# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df_csv=pd.read_csv('dailyActivity_merged.csv')
df_csv
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
cols=['Id','ActivityDate','TotalSteps','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','Calories']
new_df=df_csv[cols]

# %%
new_df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# ...

# %%
new_df['TotalMinutes'] = new_df['VeryActiveMinutes'] + \
                         new_df['FairlyActiveMinutes'] + \
                         new_df['LightlyActiveMinutes'] + \
                         new_df['SedentaryMinutes']
# Out:
# C:\Users\nourh\AppData\Local\Temp\ipykernel_31684\2392243529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['TotalMinutes'] = new_df['VeryActiveMinutes'] + \

# %%
new_df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# ...

# %%
new_df['Totalhours'] = round(new_df.TotalMinutes/60)
# Out:
# C:\Users\nourh\AppData\Local\Temp\ipykernel_31684\1939802703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Totalhours'] = round(new_df.TotalMinutes/60)

# %%
new_df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    457 non-null    int64
#  1   ActivityDate          457 non-null    object
#  2   TotalSteps            457 non-null    int64
#  3   VeryActiveMinutes     457 non-null    int64
#  4   FairlyActiveMinutes   457 non-null    int64
#  5   LightlyActiveMinutes  457 non-null    int64
#  6   SedentaryMinutes      457 non-null    int64
#  7   Calories              457 non-null    int64
#  8   TotalMinutes          457 non-null    int64
#  9   Totalhours            457 non-null    float64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 35.8+ KB

# %%
new_df['ActivityDate'] = pd.to_datetime(new_df['ActivityDate'])
new_df['DayOfWeek'] = new_df['ActivityDate'].dt.day_name()
# Out:
# C:\Users\nourh\AppData\Local\Temp\ipykernel_31684\1210599816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['ActivityDate'] = pd.to_datetime(new_df['ActivityDate'])
# C:\Users\nourh\AppData\Local\Temp\ipykernel_31684\1210599816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['DayOfWeek'] = new_df['ActivityDate'].dt.day_name()

# %%
new_df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366   2016-03-25       11004                 33
# 1    1503960366   2016-03-26       17609                 89
# 2    1503960366   2016-03-27       12736                 56
# 3    1503960366   2016-03-28       13231                 39
# 4    1503960366   2016-03-29       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391   2016-04-08       23014                 70
# 453  8877689391   2016-04-09       16470                 90
# 454  8877689391   2016-04-10       28497                128
# 455  8877689391   2016-04-11       10622                 18
# 456  8877689391   2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    457 non-null    int64
#  1   ActivityDate          457 non-null    datetime64[ns]
#  2   TotalSteps            457 non-null    int64
#  3   VeryActiveMinutes     457 non-null    int64
#  4   FairlyActiveMinutes   457 non-null    int64
#  5   LightlyActiveMinutes  457 non-null    int64
#  6   SedentaryMinutes      457 non-null    int64
#  7   Calories              457 non-null    int64
#  8   TotalMinutes          457 non-null    int64
#  9   Totalhours            457 non-null    float64
#  10  DayOfWeek             457 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(8), object(1)
# memory usage: 39.4+ KB

# %%
new_df.isnull().sum()
# Out:
# Id                      0
# ActivityDate            0
# TotalSteps              0
# VeryActiveMinutes       0
# FairlyActiveMinutes     0
# LightlyActiveMinutes    0
# SedentaryMinutes        0
# Calories                0
# TotalMinutes            0
# Totalhours              0
# DayOfWeek               0
# dtype: int64

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
new_df.describe()
# Out:
#                  Id                   ActivityDate    TotalSteps  \
# count  4.570000e+02                            457    457.000000
# mean   4.628595e+09  2016-04-04 04:40:26.258205696   6546.562363
# min    1.503960e+09            2016-03-12 00:00:00      0.000000
# 25%    2.347168e+09            2016-04-02 00:00:00   1988.000000
# 50%    4.057193e+09            2016-04-05 00:00:00   5986.000000
# 75%    6.391747e+09            2016-04-08 00:00:00  10198.000000
# max    8.877689e+09            2016-04-12 00:00:00  28497.000000
# std    2.293781e+09                            NaN   5398.493064
#
#        VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# count         457.000000           457.000000            457.000000
# mean           16.623632            13.070022            170.070022
# min             0.000000             0.000000              0.000000
# 25%             0.000000             0.000000             64.000000
# ...

# %%
plt.figure(figsize=((8,5)))
plt.hist(new_df.DayOfWeek,bins=7,color='lightskyblue',width=0.6)
plt.grid(True)
plt.xlabel('Day of week')
plt.ylabel('Freq')
plt.title('Freq by day of week')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
new_df.corr(numeric_only='True')
# Out:
#                             Id  TotalSteps  VeryActiveMinutes  \
# Id                    1.000000    0.138662           0.315967
# TotalSteps            0.138662    1.000000           0.699699
# VeryActiveMinutes     0.315967    0.699699           1.000000
# FairlyActiveMinutes   0.001878    0.238389           0.167764
# LightlyActiveMinutes -0.073104    0.654418           0.199697
# SedentaryMinutes     -0.027336   -0.285258          -0.177652
# Calories              0.290868    0.581380           0.518905
# TotalMinutes         -0.029175    0.041449          -0.001548
# Totalhours           -0.030675    0.042639           0.000756
#
#                       FairlyActiveMinutes  LightlyActiveMinutes  \
# Id                               0.001878             -0.073104
# TotalSteps                       0.238389              0.654418
# VeryActiveMinutes                0.167764              0.199697
# FairlyActiveMinutes              1.000000              0.095449
# ...

# %%
sns.heatmap(new_df.corr(numeric_only=True))
plt.figure(figsize=((3,3)))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=((5,5)))
plt.scatter(new_df.TotalSteps,new_df.Calories,c=new_df.Calories)
median_steps=7405
median_calories=2134
plt.axhline(median_calories,color='blue',label='median of calories')
plt.axvline(median_steps,color='red',label='median of steps')
plt.xlabel('Steps')
plt.ylabel('Calories')
plt.title('Calories by total steps')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=((5,5)))
plt.scatter(new_df.Totalhours,new_df.Calories,c=new_df.Calories)
median_hours=24
median_calories=2134
plt.axhline(median_calories,color='blue',label='median of calories')
plt.axvline(median_hours,color='red',label='median of hours')
plt.xlabel('hours')
plt.ylabel('Calories')
plt.title('Calories by  hours')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
VeryActiveMinutes=new_df.VeryActiveMinutes.sum()
FairlyActiveMinutes=new_df.FairlyActiveMinutes.sum()
LightlyActiveMinutes=new_df.LightlyActiveMinutes.sum()
SedentaryMinutes=new_df.SedentaryMinutes.sum()
minutes=[VeryActiveMinutes,FairlyActiveMinutes,LightlyActiveMinutes,SedentaryMinutes]
labels=['VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']
plt.figure(figsize=((8,7)))

plt.pie(minutes,labels=labels,autopct='%1.1f',explode=[0,0,0,0.1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
